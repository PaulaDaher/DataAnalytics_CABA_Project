# %% [markdown]
# ### ANEXO I: EVENTOS MASIVOS Y LOCALES BAILABLES
# Para entender un poco más el comportamiento de los datos que visualizamos en el EDA, y teniendo en cuenta que hay una concentración importante de accidentes en diciembre y enero y que además hay concentración de accidentes en las horas de madrugada, importé otras dos bases de datos con registros de los eventos masivos en la ciudad de buenos Aires y otra con registros de los locales bailables.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### EVENTOS MASIVOS:

# %%
eventos = pd.read_csv(r'DataBases\DataBases_complementarias\permisos_eventos_masivos.csv', encoding='latin1')
eventos
# Out:
#      periodo       long        lat              denominacion_evento  \
# 0     201903 -58.469089 -34.697331  EVENTOS DEPORTIVOS EN AUTODROMO
# 1     201903 -58.429086 -34.569722                      LUIS MIGUEL
# 2     201903 -58.471803 -34.592463               GROOVE OUTDOORS II
# 3     201903 -58.410465 -34.606624         FIESTA BOMBA DE CARNAVAL
# 4     201903 -58.429086 -34.569722                      SUNSETSTRIP
# ..       ...        ...        ...                              ...
# 149   201910 -58.448246 -34.590964                      SABADO EN C
# 150   201910 -58.361373 -34.619109               CHANDON WONDERLAND
# 151   201910 -58.448246 -34.590964           BUNKER FRENTE DE TODOS
# 152   201910 -58.469089 -34.697331  EVENTOS DEPORTIVOS EN AUTODROMO
# 153   201910        NaN        NaN                 SUNRISE OPEN AIR
#
#                             fecha                horario  \
# 0    1, 8, 10, 15, 22 y 29/3/2019   de 19,30 a 04,30 hrs
# ...

# %% [markdown]
# #### En este caso la base de datos de los eventos masivos es muy escasa por lo que no la vamos a tener en cuenta. Solo tiene registros del 2019 y además no tiene registros del año completo.
# Intenté encontrar una base de datos más completa pero lamentablemente no encontré, por lo que mi analisis segurmante irá dirigido por otro lado.

# %% [markdown]
# Vemos que esta base de datos es más completa, analizaremos la distribucion de los locales por comuna
